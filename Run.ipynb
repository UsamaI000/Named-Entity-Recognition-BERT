# %%
# Checking gpu assigned by colab
# !nvidia-smi
# Out:
# Sun Mar  7 08:02:47 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# Copying Project directory from drive to colab
#!cp -r "./drive/MyDrive/BERT_NER" "./"

# %%
# Downloading nltk and transformers
import nltk
nltk.download('all')
# !pip install transformers==4.0 contractions torch==1.3.1

# %%
# Start training
# %run "./BERT_NER_final/src/train.py"
# Out:
# Loading and pre-processing data....
#
# Done
# Length of dataset is: 2779
# ...
# 100%|██████████| 87/87 [00:15<00:00,  5.61it/s]
# Epoch # 1
# 	Train Loss = 0.2862202309043471, Test Loss = 0.1537196017031012,
# 	Train Acc = 0.9196950830140485, Test Acc = 0.9815722495894907,
# 	Train F1 score = 0.0530080716182639, Test F1 score = 0.04802051477924834
# ...
# 100%|██████████| 87/87 [00:15<00:00,  5.53it/s]
# Epoch # 2
# 	Train Loss = 0.1239889345463665, Test Loss = 0.09348494401094558,
# 	Train Acc = 0.9770418263090677, Test Acc = 0.9748535851122059,
# 	Train F1 score = 0.37943631774460246, Test F1 score = 0.7412058618851534
# ...
# 100%|██████████| 87/87 [00:15<00:00,  5.52it/s]
# Epoch # 3
# 	Train Loss = 0.08798900514955264, Test Loss = 0.07790098968764832,
# 	Train Acc = 0.9754294380587484, Test Acc = 0.9756964969896007,
# 	Train F1 score = 0.714289543443218, Test F1 score = 0.82392393589591
# ...
# 100%|██████████| 87/87 [00:15<00:00,  5.55it/s]
# Epoch # 4
# ...

# %%
# !cp -r './BERT_NER_final' './drive/MyDrive/'
